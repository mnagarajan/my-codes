# %% [markdown]
# <a href="https://colab.research.google.com/github/mnagarajan/my-codes/blob/main/how_to_convert_to_html.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get install -y pandoc
# !pip install pypandoc
# !pip install nbconvert
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/ColabNotebooks/

# !pwd   # print working directory
# !ls -l
# !ls -d

#convert file to html

# !jupyter nbconvert --to html --template custom.tpl Nagarajan_AAI_500_M3_Assignment.ipynb

#  uses the custom.tpl template located in the specified template directory.
# !jupyter nbconvert --to html --template custom.tpl --template-path /path/to/your/templates Nagarajan_AAI_500_M3_Assignment.ipynb
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# pandoc is already the newest version (2.9.2.1-3ubuntu2).
# 0 upgraded, 0 newly installed, 0 to remove and 53 not upgraded.
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/ColabNotebooks
# /content/drive/MyDrive/ColabNotebooks
# total 3770
# -rw------- 1 root root   67549 Sep  8 12:50 'Comprehensive Introduction to Python Programming  (1).ipynb'
# -rw------- 1 root root   63820 Sep  9 09:34 'Comprehensive Introduction to Python Programming .ipynb'
# -rw------- 1 root root     160 Sep 27 00:12  custom.tpl
# -rw------- 1 root root   11054 Sep 27 00:18 'how to convert to html.ipynb'
# -rw------- 1 root root   28310 Sep 18 16:15 'making pdf.ipynb'
# -rw------- 1 root root 1031743 Sep 12 02:29 'myStudy - Sets and Probabilities.ipynb'
# ...

# %%
from IPython.core.display import HTML
display(HTML("<style>body { font-size: 16pt; }</style>"))
# Out:
# <style>body { font-size: 16pt; }</style>

# %%
# !jupyter nbconvert --help-all
# Out:
# This application is used to convert notebook files (*.ipynb)
#         to various other formats.
#
#         WARNING: THE COMMANDLINE INTERFACE MAY CHANGE IN FUTURE RELEASES.
#
# Options
# ...
# The options below are convenience aliases to configurable class-options,
# as listed in the "Equivalent to" description-line of the aliases.
# To see all configurable class-options for some <cmd>, use:
#     <cmd> --help-all
#
# --debug
#     set log level to logging.DEBUG (maximize logging output)
#     Equivalent to: [--Application.log_level=10]
# --show-config
#     Show the application's configuration (human-readable format)
#     Equivalent to: [--Application.show_config=True]
# --show-config-json
#     Show the application's configuration (json format)
#     Equivalent to: [--Application.show_config_json=True]
# --generate-config
#     generate default config file
#     Equivalent to: [--JupyterApp.generate_config=True]
# -y
#     Answer yes to any questions instead of prompting.
# ...

# %%
# !jupyter nbconvert --to html --template full
# Out:
# This application is used to convert notebook files (*.ipynb)
#         to various other formats.
#
#         WARNING: THE COMMANDLINE INTERFACE MAY CHANGE IN FUTURE RELEASES.
#
# Options
# ...
# The options below are convenience aliases to configurable class-options,
# as listed in the "Equivalent to" description-line of the aliases.
# To see all configurable class-options for some <cmd>, use:
#     <cmd> --help-all
#
# --debug
#     set log level to logging.DEBUG (maximize logging output)
#     Equivalent to: [--Application.log_level=10]
# --show-config
#     Show the application's configuration (human-readable format)
#     Equivalent to: [--Application.show_config=True]
# --show-config-json
#     Show the application's configuration (json format)
#     Equivalent to: [--Application.show_config_json=True]
# --generate-config
#     generate default config file
#     Equivalent to: [--JupyterApp.generate_config=True]
# -y
#     Answer yes to any questions instead of prompting.
# ...
